# %%
from cicids_preprocessing import load_dataset, clean_dataset

DATA_PATH = "../data/CICIDS-2017"

df_test = load_dataset(DATA_PATH)
X, y, le = clean_dataset(df_test)

print(X.shape)
print(y.shape)
print(le.classes_)
# Out:
# Loading: Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Morning.pcap_ISCX.csv
# Loading: Monday-WorkingHours.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# Loading: Tuesday-WorkingHours.pcap_ISCX.csv
# Loading: Wednesday-workingHours.pcap_ISCX.csv
# (399675, 78)
# (399675,)
# ['ATTACK' 'BENIGN']

# %%
# !python cicids_train_model.py
# Out:
# Loading: Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Morning.pcap_ISCX.csv
# Loading: Monday-WorkingHours.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# Loading: Tuesday-WorkingHours.pcap_ISCX.csv
# Loading: Wednesday-workingHours.pcap_ISCX.csv
# Final X shape: (399675, 78)
# Final y shape: (399675,)
# Classes: ['ATTACK' 'BENIGN']
# Training started...
# Training completed!
# Model saved successfully!

# %%
# !python cicids_model_evaluation.py
# Out:
# Loading: Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# Loading: Friday-WorkingHours-Morning.pcap_ISCX.csv
# Loading: Monday-WorkingHours.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# Loading: Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# Loading: Tuesday-WorkingHours.pcap_ISCX.csv
# Loading: Wednesday-workingHours.pcap_ISCX.csv
# ...
# Random Forest Evaluation
# ...
# Accuracy : 0.9985112904234691
# Precision: 0.9992560676978395
# Recall   : 0.9988999922534666
# F1 Score : 0.9990779982489715
# ROC-AUC  : 0.9999356841419702
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#       ATTACK       1.00      1.00      1.00     15390
#       BENIGN       1.00      1.00      1.00     64545
#
#     accuracy                           1.00     79935
#    macro avg       1.00      1.00      1.00     79935
# ...

# %%
from nsl_kdd_preprocessing import load_and_preprocess

X_train, X_test, y_train, y_test = load_and_preprocess()

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

print("Classes:", y_train.unique())
print("Class counts:")
print(y_train.value_counts())
# Out:
# X_train shape: (100778, 41)
# X_test shape: (25195, 41)
# y_train shape: (100778,)
# y_test shape: (25195,)
# Classes: [0 1]
# Class counts:
# label
# 0    53874
# 1    46904
# Name: count, dtype: int64

# %%
# !python nsl_kdd_train_model.py
# Out:
# Training NSL-KDD Random Forest model...
# Model saved successfully at ../models/nsl-kdd_anomaly_model.pkl

# %%
# !python nsl_kdd_model_evaluation.py
# Out:
# ...
# Random Forest Evaluation - NSL-KDD
# ...
# Training Accuracy : 0.999593165174939
# Testing Accuracy  : 0.9990871204604088
# Precision         : 0.9994878361075544
# Recall            : 0.9985502302575473
# F1 Score          : 0.9990188131905635
# ROC-AUC           : 0.9999923197464436
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     13469
#       Attack       1.00      1.00      1.00     11726
#
#     accuracy                           1.00     25195
#    macro avg       1.00      1.00      1.00     25195
# weighted avg       1.00      1.00      1.00     25195
#
# Confusion Matrix
#
# [[13463     6]
#  [   17 11709]]
#
# ...
# Reports and PNG files saved successfully!
# ...
